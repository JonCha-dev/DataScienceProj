# %% [markdown]
# # COGS 108 - Data Checkpoint

# %% [markdown]
# # Names
#
# - Allison Bhavsar
# - Jon Chang
# - Mikaela Grenion
# - Nathan Nakamura
# - Tilak Patel

# %% [markdown]
# <a id='research_question'></a>
# # Research Question

# %% [markdown]
# What is the relationship between race and reason for wrongful conviction among exonerees in the United States?

# %% [markdown]
# # Dataset(s)

# %% [markdown]
# This dataset is from the National Registry of Exonerations that is keeping track of all known exonerations in the United States from 1989 to present. There are 2765 observations (exonerees) with their names, age, race, sex, location, crimes commited, and 15 variables for all types of exonerations.
#
# - Dataset Name: The National Registry of Exonerations
# - Link to the dataset: https://www.law.umich.edu/special/exoneration/Pages/detaillist.aspx
# - Number of observations: 2765

# %% [markdown]
# # Setup

# %%
import numpy as np
import pandas as pd
df = pd.read_excel ('data/publicspreadsheet.xlsx')
df
# Out:
#        Last Name    First Name   Age      Race   Sex           State  \
# 0         Abbitt       Joseph   31.0     Black  Male  North Carolina
# 1          Abdal  Warith Habib  43.0     Black  Male        New York
# 2      Abernathy   Christopher  17.0     White  Male        Illinois
# 3          Abney       Quentin  32.0     Black  Male        New York
# 4          Acero       Longino  35.0  Hispanic  Male      California
# ...          ...           ...   ...       ...   ...             ...
# 2760     Zawacki       Richard  38.0     White  Male         Indiana
# 2761      Zimmer        Walter  40.0     White  Male            Ohio
# 2762   Zimmerman          Evan  53.0     White  Male       Wisconsin
# 2763  Zinkiewicz        Tyrone  38.0     White  Male            Ohio
# 2764      Zomber       Michael  53.0     White  Male          Fed-PA
#
#            County            Tags        Worst Crime Display  \
# 0         Forsyth          CV;#IO            Child Sex Abuse
# 1            Erie              IO             Sexual Assault
# 2            Cook  CIU;#CV;#H;#IO                     Murder
# 3        New York              CV                    Robbery
# 4     Santa Clara           NC;#P  Sex Offender Registration
# ...           ...             ...                        ...
# 2760   Huntington          CV;#NC            Child Sex Abuse
# 2761     Cuyahoga      CDC;#H;#IO               Manslaughter
# 2762        Dodge           H;#IO                     Murder
# 2763   Montgomery          CV;#NC    Other Nonviolent Felony
# 2764    (Eastern)             FED                      Fraud
#
#                                List Add'l Crimes Recode  ...    *   FC  MWID  \
# 0     Sexual Assault;#Kidnapping;#Burglary/Unlawful ...  ...  NaN  NaN  MWID
# 1                                               Robbery  ...  NaN  NaN  MWID
# 2                                         Rape;#Robbery  ...  NaN   FC   NaN
# 3                                                   NaN  ...  NaN  NaN  MWID
# 4                                                   NaN  ...  NaN  NaN   NaN
# ...                                                 ...  ...  ...  ...   ...
# 2760                                                NaN  ...  NaN  NaN   NaN
# 2761  Attempted Murder;#Robbery;#Assault;#Kidnapping...  ...    *  NaN   NaN
# 2762                                                NaN  ...    *   FC   NaN
# 2763                                                NaN  ...  NaN  NaN   NaN
# 2764                                                NaN  ...  NaN  NaN   NaN
#
#       F/MFE  P/FA   OM  ILD Posting Date          OM Tags Occurred
# 0       NaN   NaN  NaN  NaN   2011-09-01              NaN     1991
# 1     F/MFE   NaN   OM  NaN   2011-08-29   OF;#WH;#NW;#WT     1982
# 2       NaN  P/FA   OM  NaN   2015-02-13  OF;#WH;#NW;#INT     1984
# 3       NaN   NaN  NaN  NaN   2019-05-13              NaN     2005
# 4       NaN   NaN  NaN  ILD   2011-08-29              NaN     1994
# ...     ...   ...  ...  ...          ...              ...      ...
# 2760    NaN  P/FA  NaN  NaN   2017-08-08              NaN     2000
# 2761  F/MFE  P/FA   OM  NaN   2013-10-04   FA;#WH;#NW;#PJ     1997
# 2762    NaN   NaN  NaN  ILD   2011-08-29              NaN     2000
# 2763    NaN  P/FA   OM  NaN   2014-10-25           PR;#WH     1988
# 2764    NaN   NaN   OM  NaN   2011-08-29           PR;#WH     2001
#
# [2765 rows x 24 columns]

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Describe your data cleaning steps here.

# %%
# Dropped columns irrelevant to our research question and dropped columns with identifying information like names
df2 = df.drop(["Last Name", "First Name", "Sex", "County", "State", "Posting Date", "Tags", "OM Tags", "*", "List Add'l Crimes Recode"], axis=1)

# Dropped rows where race infornation is unknown (either "Other" or "Don't Know")
df2 = df2[(df2['Race'] != "Don't Know") & (df2['Race'] != 'Other')]

# %%
# Renamed acronyms with clearer names
df2 = df2.rename(columns={"FC" : "False Confession", "MWID": "Witness Misidentification", "F/MFE": "False Evidence", "P/FA": "Perjury", "OM": "Offical Misconduct", "ILD": "Legal Defense"})

# %%
# Made exoneration reason columns booleans (1 if it was a reason, 0 otherwise replacing NaNs)
df2.update(df2[["DNA", "False Confession", "Witness Misidentification","False Evidence","Perjury","Offical Misconduct","Legal Defense"]].fillna(0))
df2 = df2.replace({"DNA": 1,"FC" :1,"MWID":1, "F/MFE": 1, "P/FA": 1, "OM": 1, "ILD": 1})

# %%
df2
# Out:
#        Age      Race        Worst Crime Display              Sentence  \
# 0     31.0     Black            Child Sex Abuse                  Life
# 1     43.0     Black             Sexual Assault            20 to Life
# 2     17.0     White                     Murder   Life without parole
# 3     32.0     Black                    Robbery            20 to Life
# 4     35.0  Hispanic  Sex Offender Registration  2 years and 4 months
# ...    ...       ...                        ...                   ...
# 2760  38.0     White            Child Sex Abuse               4 years
# 2761  40.0     White               Manslaughter              50 years
# 2762  53.0     White                     Murder                  Life
# 2763  38.0     White    Other Nonviolent Felony         5 to 15 years
# 2764  53.0     White                      Fraud  2 years and 6 months
#
#       Convicted  Exonerated  DNA  False Confession  Witness Misidentification  \
# 0          1995        2009    1                 0                          1
# 1          1983        1999    1                 0                          1
# 2          1987        2015    1                 1                          0
# 3          2006        2012    0                 0                          1
# 4          1994        2006    0                 0                          0
# ...         ...         ...  ...               ...                        ...
# 2760       2000        2001    0                 0                          0
# 2761       1998        2011    1                 0                          0
# 2762       2001        2005    1                 1                          0
# 2763       1988        1992    0                 0                          0
# 2764       2003        2009    0                 0                          0
#
#       False Evidence  Perjury  Offical Misconduct  Legal Defense  Occurred
# 0                  0        0                   0              0      1991
# 1                  1        0                   1              0      1982
# 2                  0        1                   1              0      1984
# 3                  0        0                   0              0      2005
# 4                  0        0                   0              1      1994
# ...              ...      ...                 ...            ...       ...
# 2760               0        1                   0              0      2000
# 2761               1        1                   1              0      1997
# 2762               0        0                   0              1      2000
# 2763               0        1                   1              0      1988
# 2764               0        0                   1              0      2001
#
# [2745 rows x 14 columns]

# %% [markdown]
# In order to get the data into a usable format, we dropped columns corresponding to unnecessary variables and personal information, and rows where race information was missing since race is relevant to our research question. We also renamed the exoneration reason columns to make their meanings more clear, and we changed their values to 1s and 0s to make it easier to perform analysis on these variables.
